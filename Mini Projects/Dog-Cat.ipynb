# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = {
    'weight':[4.5,20.0,5.0,22.0,3.8,18.5,4.2,21.0],
    'height':[23,45,25,50,21,43,22,48],
    'ear_size':[6.5,10.0,7.0,11.5,6.0,9.0,6.8,10.5],
    'tail_length':[25,30,24,35,22,32,23,33],
    'label':[0,1,0,1,0,1,0,1]
}

# %%
df= pd.DataFrame(data)

# %%
X = df[['weight','height','ear_size','tail_length']]
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
new_sample = [[5.0,24,6.8,23]]
prediction = model.predict(new_sample)
print("Predicted label (0=cat, 1=dog):",prediction[0])
# Out:
# Predicted label (0=cat, 1=dog): 0
# C:\Users\Mihir's Latitude\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
